# %%
# !pip install langchain-groq
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 719.6 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.6/396.6 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.5/290.5 kB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model_name="llama-3.1-70b-versatile" ,
    groq_api_key="API_KEY",
    temperature=0
)

response = llm.invoke("Most popular programming language")
print(response.content)
# Out:
# The most popular programming language can vary depending on the source, methodology, and time frame considered. However, based on various indices and reports, here are some of the most popular programming languages:
#
# 1. **JavaScript**: JavaScript is often considered the most popular programming language, especially for web development. It's used by over 90% of websites for client-side scripting.
# 2. **Python**: Python is a close second, widely used for data science, machine learning, web development, and automation. Its popularity has been growing rapidly in recent years.
# 3. **Java**: Java is a popular language for Android app development, web development, and enterprise software development.
# 4. **C++**: C++ is a high-performance language used for building operating systems, games, and other high-performance applications.
# 5. **C#**: C# is a modern, object-oriented language developed by Microsoft, widely used for Windows and web application development.
#
# ...
